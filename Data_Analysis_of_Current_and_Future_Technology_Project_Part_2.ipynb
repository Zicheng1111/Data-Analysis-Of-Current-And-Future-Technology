# %% [markdown]
# **Analyze the trend of technology**

# %% [markdown]
# Import relevant modules

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Install Google Drive access

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Set Authorization for Google

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Download the file

# %%
fileDownloaded = drive.CreateFile({"id":"1B6ctCVJ-dtL1S9D-klwlLs06doSXRG31"})

# %%
fileDownloaded.GetContentFile("survey_data_technologies_normalised.csv")

# %% [markdown]
# Read the file

# %%
df=pd.read_csv("survey_data_technologies_normalised.csv")
df
# Out:
#        Respondent LanguageWorkedWith  ... BlockchainOrg BlockchainIs
# 0             NaN                NaN  ...           NaN          NaN
# 1             4.0                  C  ...           NaN          NaN
# 2             4.0                C++  ...           NaN          NaN
# 3             4.0                 C#  ...           NaN          NaN
# 4             4.0             Python  ...           NaN          NaN
# ...           ...                ...  ...           ...          ...
# 74585     25142.0                 Go  ...           NaN          NaN
# 74586     25142.0           HTML/CSS  ...           NaN          NaN
# 74587     25142.0                PHP  ...           NaN          NaN
# 74588     25142.0             Python  ...           NaN          NaN
# 74589     25142.0                  R  ...           NaN          NaN
#
# [74590 rows x 14 columns]

# %% [markdown]
# Drop the first row

# %%
df.drop([0,0],axis=0,inplace=True)
df
# Out:
#        Respondent LanguageWorkedWith  ... BlockchainOrg BlockchainIs
# 1             4.0                  C  ...           NaN          NaN
# 2             4.0                C++  ...           NaN          NaN
# 3             4.0                 C#  ...           NaN          NaN
# 4             4.0             Python  ...           NaN          NaN
# 5             4.0                SQL  ...           NaN          NaN
# ...           ...                ...  ...           ...          ...
# 74585     25142.0                 Go  ...           NaN          NaN
# 74586     25142.0           HTML/CSS  ...           NaN          NaN
# 74587     25142.0                PHP  ...           NaN          NaN
# 74588     25142.0             Python  ...           NaN          NaN
# 74589     25142.0                  R  ...           NaN          NaN
#
# [74589 rows x 14 columns]

# %% [markdown]
# Rename "OpSys" to "OperationSystem"

# %%
df.rename(columns={"OpSys":"OperationSystem"},inplace=True)
df
# Out:
#        Respondent LanguageWorkedWith  ... BlockchainOrg BlockchainIs
# 1             4.0                  C  ...           NaN          NaN
# 2             4.0                C++  ...           NaN          NaN
# 3             4.0                 C#  ...           NaN          NaN
# 4             4.0             Python  ...           NaN          NaN
# 5             4.0                SQL  ...           NaN          NaN
# ...           ...                ...  ...           ...          ...
# 74585     25142.0                 Go  ...           NaN          NaN
# 74586     25142.0           HTML/CSS  ...           NaN          NaN
# 74587     25142.0                PHP  ...           NaN          NaN
# 74588     25142.0             Python  ...           NaN          NaN
# 74589     25142.0                  R  ...           NaN          NaN
#
# [74589 rows x 14 columns]

# %% [markdown]
# Drop all empty columns

# %%
df.drop(["OperationSystem","Containers","BlockchainOrg","BlockchainIs"],axis=1,inplace=True)
df
# Out:
#        Respondent LanguageWorkedWith  ... WebFrameDesireNextYear          DevEnviron
# 1             4.0                  C  ...                    NaN             Eclipse
# 2             4.0                C++  ...                    NaN                 Vim
# 3             4.0                 C#  ...                    NaN       Visual Studio
# 4             4.0             Python  ...                    NaN  Visual Studio Code
# 5             4.0                SQL  ...                    NaN                 NaN
# ...           ...                ...  ...                    ...                 ...
# 74585     25142.0                 Go  ...                    NaN                 NaN
# 74586     25142.0           HTML/CSS  ...                    NaN                 NaN
# 74587     25142.0                PHP  ...                    NaN                 NaN
# 74588     25142.0             Python  ...                    NaN                 NaN
# 74589     25142.0                  R  ...                    NaN                 NaN
#
# [74589 rows x 10 columns]

# %% [markdown]
# Export to csv in Google Drive

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
df.to_csv('survey_data_technologies_normalised_cleaned.csv')
# !cp survey_data_technologies_normalised_cleaned.csv "drive/My Drive"

# %% [markdown]
#  Grab information about development environment

# %%
development_environment_data=df[['Respondent','DevEnviron']]
development_environment_data
# Out:
#        Respondent          DevEnviron
# 1             4.0             Eclipse
# 2             4.0                 Vim
# 3             4.0       Visual Studio
# 4             4.0  Visual Studio Code
# 5             4.0                 NaN
# ...           ...                 ...
# 74585     25142.0                 NaN
# 74586     25142.0                 NaN
# 74587     25142.0                 NaN
# 74588     25142.0                 NaN
# 74589     25142.0                 NaN
#
# [74589 rows x 2 columns]

# %% [markdown]
# Rename "DevEnviron" to "DevelopmentEnvironment"

# %%
development_environment_data.rename(columns={"DevEnviron":"DevelopmentEnvironment"},inplace=True)
development_environment_data
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        Respondent DevelopmentEnvironment
# 1             4.0                Eclipse
# 2             4.0                    Vim
# 3             4.0          Visual Studio
# 4             4.0     Visual Studio Code
# 5             4.0                    NaN
# ...           ...                    ...
# 74585     25142.0                    NaN
# 74586     25142.0                    NaN
# 74587     25142.0                    NaN
# 74588     25142.0                    NaN
# 74589     25142.0                    NaN
#
# [74589 rows x 2 columns]

# %% [markdown]
# Group the data

# %%
grouped_development_environment_data=development_environment_data.groupby(by="DevelopmentEnvironment",as_index=False).sum()
grouped_development_environment_data
# Out:
#    DevelopmentEnvironment  Respondent
# 0          Android Studio  20604062.0
# 1                    Atom  16266404.0
# 2                    Coda    636080.0
# 3                 Eclipse  17059259.0
# 4                   Emacs   5642018.0
# 5       IPython / Jupyter  12191794.0
# 6                IntelliJ  38573607.0
# 7                  Komodo    300216.0
# 8             Light Table     84553.0
# 9                NetBeans   6225417.0
# 10              Notepad++  42803781.0
# 11               PHPStorm  11797977.0
# 12                PyCharm  18234655.0
# 13                RStudio   3864638.0
# 14               RubyMine   1989615.0
# 15           Sublime Text  32449614.0
# 16               TextMate    912771.0
# 17                    Vim  37487821.0
# 18          Visual Studio  50192831.0
# 19     Visual Studio Code  82425796.0
# 20                  Xcode  12676158.0
# 21                   Zend    214977.0

# %% [markdown]
# Extract top 7 development environments

# %%
top_7_development_environment=grouped_development_environment_data.head(7)
top_7_development_environment
# Out:
#   DevelopmentEnvironment  Respondent
# 0         Android Studio  20604062.0
# 1                   Atom  16266404.0
# 2                   Coda    636080.0
# 3                Eclipse  17059259.0
# 4                  Emacs   5642018.0
# 5      IPython / Jupyter  12191794.0
# 6               IntelliJ  38573607.0

# %%
top_7_development_environment.plot(kind="barh",x="DevelopmentEnvironment",y="Respondent",color="orange",figsize=(15,9))
plt.title("Top 7 Development Environment")
plt.xlabel("Development Environment")
plt.ylabel("Respondents")
plt.show()
